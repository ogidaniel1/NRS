# %%
# importing necessary libaries

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import xgboost as xgb
from catboost import CatBoostClassifier
import joblib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[529], line 7
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn.metrics import accuracy_score
# ----> 7 import xgboost as xgb
#       8 from catboost import CatBoostClassifier
#       9 import joblib
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
# loading the dataset

df = pd.read_csv('DEALS PREDICT_NEW_check.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#    S/N      DATE NAME_OF_ENTITY                      NATURE_OF_BUSINESS  \
# 0    1  1/2/2023       COM10001                         RICE PROCESSING
# 1    2  1/2/2023       COM10002  FERTILIZER DISTRIBUTION ACROSS ADAMAWA
# 2    3  1/2/2023       COM10003                     BULL FEED FINISHING
# 3    4  1/2/2023       COM10004                     BULL FEED FINISHING
# 4    5  1/2/2023       COM10005                     BULL FEED FINISHING
#
#   BUSINESS_PROJECT CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER  \
# 0         EXISTING                              OB10001
# 1         EXISTING                              OB10002
# 2         EXISTING                              OB10003
# 3         EXISTING                              OB10004
# 4         EXISTING                              OB10005
#
#    PROPOSED_FACILITY_AMOUNT          PURPOSE_OF_FACILITY VALUE_CHAIN_CATEGORY  \
# 0              2.000000e+09  WORKING CAPITAL ENHANCEMENT            MIDSTREAM
# 1              5.000000e+07  WORKING CAPITAL ENHANCEMENT         PRE-UPSTREAM
# 2              9.000000e+06  WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 3              1.000000e+05  WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 4              5.000000e+06  WORKING CAPITAL ENHANCEMENT             UPSTREAM
#
#         NAME_OF_BANK  ...    SECURITY_PROPOSED FEASIBILITY_STUDY_AVAILABLE  \
# 0  FIDELITY BANK PLC  ...                  NIL                         YES
# 1  FIDELITY BANK PLC  ...                  NIL                         YES
# 2       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
# 3       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
# 4       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
#
#   HIGHLIGHTS_OF_DISCUSSION RM_BM_NAME_PHONE_NUMBER RM_BM_EMAIL  \
# 0                      NaN                     NaN         NaN
# 1                      NIL                     NIL         NIL
# 2                      NIL                     NIL         NIL
# 3                      NIL                     NIL         NIL
# 4                      NIL                     NIL         NIL
#
#                                        STATUS_UPDATE  \
# 0  WE AREAWAITING CREDIT COMMITY DECITION ON WEAT...
# 1  WE ARE CURRENTLY WAITING FOR THE CLIENT TO CHO...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           CHALLENGES PROPOSED_NEXT_STEPS  \
# 0                                               NONE                 NaN
# 1  THE CLIENT IS ONLY WILLING TO DISTRIBUTE CRYST...             ONBOARD
# 2                                                NaN                 NaN
# 3                                                NaN                 NaN
# 4                                                NaN                 NaN
#
#      STATE TARGET
# 0  ADAMAWA      1
# 1  ADAMAWA      1
# 2  ADAMAWA      1
# 3  ADAMAWA      0
# 4  ADAMAWA      1
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['S/N', 'DATE', 'NAME_OF_ENTITY', 'NATURE_OF_BUSINESS',
#        'BUSINESS_PROJECT', 'CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER',
#        'PROPOSED_FACILITY_AMOUNT', 'PURPOSE_OF_FACILITY',
#        'VALUE_CHAIN_CATEGORY', 'NAME_OF_BANK', 'BORROWING_RELATIONSHIP',
#        'FRESH_LOAN_REQUEST', 'REQUEST_SUBMITTED_TO_BANK', 'SECURITY_PROPOSED',
#        'FEASIBILITY_STUDY_AVAILABLE', 'HIGHLIGHTS_OF_DISCUSSION',
#        'RM_BM_NAME_PHONE_NUMBER', 'RM_BM_EMAIL', 'STATUS_UPDATE', 'CHALLENGES',
#        'PROPOSED_NEXT_STEPS', 'STATE', 'TARGET'],
#       dtype='object')

# %%
# short statistical description of dataset 

df.describe
# Out:
# <bound method NDFrame.describe of      S/N        DATE          NAME_OF_ENTITY  \
# 0      1    1/2/2023                COM10001
# 1      2    1/2/2023                COM10002
# 2      3    1/2/2023                COM10003
# 3      4    1/2/2023                COM10004
# 4      5    1/2/2023                COM10005
# ..   ...         ...                     ...
# 238  239  31/03/2024      NOOR NGESA NIG LTD
# 239  240  30/01/2024             ABS ZUGACHI
# 240  241    5/5/2024    Bauchi Meat Factory
# 241  242    5/5/2024  ZAKWARAM BAFFA NIG LTD
# 242  243    5/5/2024       BAUCHI FERTILIZER
#
#                          NATURE_OF_BUSINESS BUSINESS_PROJECT  \
# 0                           RICE PROCESSING         EXISTING
# 1    FERTILIZER DISTRIBUTION ACROSS ADAMAWA         EXISTING
# 2                       BULL FEED FINISHING         EXISTING
# 3                       BULL FEED FINISHING         EXISTING
# 4                       BULL FEED FINISHING         EXISTING
# ..                                      ...              ...
# 238                        RICE CULTIVATION         EXISTING
# 239                   FERTILIZER FINANCING          EXISTING
# 240                        Meat Processing          EXISTING
# 241                                 POULTRY         EXISTING
# 242                    FERTILIZER BLENDINFG         EXISTING
#
#     CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER  PROPOSED_FACILITY_AMOUNT  \
# 0                                OB10001              2.000000e+09
# 1                                OB10002              5.000000e+07
# 2                                OB10003              9.000000e+06
# 3                                OB10004              1.000000e+05
# 4                                OB10005              5.000000e+06
# ..                                   ...                       ...
# 238                              OB10239              2.000000e+08
# 239                              OB10240              5.000000e+08
# 240                              OB10241              3.000000e+09
# 241                              OB10242              2.000000e+08
# 242                              OB10243              5.000000e+09
#
#                                    PURPOSE_OF_FACILITY VALUE_CHAIN_CATEGORY  \
# 0                          WORKING CAPITAL ENHANCEMENT            MIDSTREAM
# 1                          WORKING CAPITAL ENHANCEMENT         PRE-UPSTREAM
# 2                          WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 3                          WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 4                          WORKING CAPITAL ENHANCEMENT             UPSTREAM
# ..                                                 ...                  ...
# 238                     TO FINANCE CULTIVATION OF RICE             UPSTREAM
# 239                               FERTILIZER PURCHASE          PRE-UPSTREAM
# 240  working capital and reviving cold room and oth...            MIDSTREAM
# 241                                          EXPANSION             UPSTREAM
# 242                                          EXPANSION            MIDSTREAM
#
#           NAME_OF_BANK  ...                             SECURITY_PROPOSED  \
# 0    FIDELITY BANK PLC  ...                                           NIL
# 1    FIDELITY BANK PLC  ...                                           NIL
# 2         STANBIC IBTC  ...                           EQUITY CONTRIBUTION
# 3         STANBIC IBTC  ...                           EQUITY CONTRIBUTION
# 4         STANBIC IBTC  ...                           EQUITY CONTRIBUTION
# ..                 ...  ...                                           ...
# 238         JAIZ BANK   ...  25% EQUITY CONTRIBUTION AND NIRSAL GUARANTEE
# 239           STERLING  ...                                        EQUITY
# 240     Sterling Bank   ...             Factory and 50% NIRSAL guarantee
# 241           STERLING  ...                      LANDED PROPERTY AND ISPO
# 242           STERLING  ...                                          ISPO
#
#     FEASIBILITY_STUDY_AVAILABLE HIGHLIGHTS_OF_DISCUSSION  \
# 0                           YES                      NaN
# 1                           YES                      NIL
# 2                           YES                      NIL
# 3                           YES                      NIL
# 4                           YES                      NIL
# ..                          ...                      ...
# 238                         YES                      NIL
# 239                          NO                      NIL
# 240                         YES                      NIL
# 241                          NO                      NIL
# 242                         NIL                      NIL
#
#     RM_BM_NAME_PHONE_NUMBER RM_BM_EMAIL  \
# 0                       NaN         NaN
# 1                       NIL         NIL
# 2                       NIL         NIL
# 3                       NIL         NIL
# 4                       NIL         NIL
# ..                      ...         ...
# 238                     NIL         NIL
# 239                     NIL         NIL
# 240                     NIL         NIL
# 241                     NIL         NIL
# 242                     NIL         NIL
#
#                                          STATUS_UPDATE  \
# 0    WE AREAWAITING CREDIT COMMITY DECITION ON WEAT...
# 1    WE ARE CURRENTLY WAITING FOR THE CLIENT TO CHO...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 238                              DISCUSSION IS ONGOING
# 239                                                NaN
# 240  The bank had a fruitful discussion with bauchi...
# 241     The official request were submitted yesterday.
# 242          formal request will be ready after sallah
#
#                                             CHALLENGES  \
# 0                                                 NONE
# 1    THE CLIENT IS ONLY WILLING TO DISTRIBUTE CRYST...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 238                                DELAY FROM THE BANK
# 239                    LOAN AMOUNT YET TO BE AGREED ON
# 240  High operational cost may be affect the daily ...
# 241                                        Nil for now
# 242                       interest rate and moratarium
#
#                                    PROPOSED_NEXT_STEPS    STATE TARGET
# 0                                                  NaN  ADAMAWA      1
# 1                                              ONBOARD  ADAMAWA      1
# 2                                                  NaN  ADAMAWA      1
# 3                                                  NaN  ADAMAWA      0
# 4                                                  NaN  ADAMAWA      1
# ..                                                 ...      ...    ...
# 238                CONTINUE FOLLOWING UP WITH THE BANK   TARABA      0
# 239                          WAITING TO HEAR FROM BANK    GOMBE      0
# 240  Negotiating with bank to consider lower intere...   BAUCHI      0
# 241                     waiting for the bank response.   BAUCHI      0
# 242      to meet with the bank and company next sallah   BAUCHI      0
#
# [243 rows x 23 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   S/N                                   243 non-null    int64
#  1   DATE                                  243 non-null    object
#  2   NAME_OF_ENTITY                        241 non-null    object
#  3   NATURE_OF_BUSINESS                    242 non-null    object
#  4   BUSINESS_PROJECT                      243 non-null    object
#  5   CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER  243 non-null    object
#  6   PROPOSED_FACILITY_AMOUNT              243 non-null    float64
#  7   PURPOSE_OF_FACILITY                   240 non-null    object
#  8   VALUE_CHAIN_CATEGORY                  243 non-null    object
#  9   NAME_OF_BANK                          221 non-null    object
#  10  BORROWING_RELATIONSHIP                243 non-null    object
#  11  FRESH_LOAN_REQUEST                    243 non-null    object
#  12  REQUEST_SUBMITTED_TO_BANK             243 non-null    object
#  13  SECURITY_PROPOSED                     230 non-null    object
#  14  FEASIBILITY_STUDY_AVAILABLE           243 non-null    object
#  15  HIGHLIGHTS_OF_DISCUSSION              242 non-null    object
#  16  RM_BM_NAME_PHONE_NUMBER               242 non-null    object
#  17  RM_BM_EMAIL                           242 non-null    object
#  18  STATUS_UPDATE                         210 non-null    object
#  19  CHALLENGES                            170 non-null    object
#  20  PROPOSED_NEXT_STEPS                   200 non-null    object
#  21  STATE                                 240 non-null    object
#  22  TARGET                                243 non-null    int64
# dtypes: float64(1), int64(2), object(20)
# memory usage: 43.8+ KB

# %%
df.isna().sum()
# Out:
# S/N                                      0
# DATE                                     0
# NAME_OF_ENTITY                           2
# NATURE_OF_BUSINESS                       1
# BUSINESS_PROJECT                         0
# CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER     0
# PROPOSED_FACILITY_AMOUNT                 0
# PURPOSE_OF_FACILITY                      3
# VALUE_CHAIN_CATEGORY                     0
# NAME_OF_BANK                            22
# BORROWING_RELATIONSHIP                   0
# FRESH_LOAN_REQUEST                       0
# REQUEST_SUBMITTED_TO_BANK                0
# SECURITY_PROPOSED                       13
# FEASIBILITY_STUDY_AVAILABLE              0
# HIGHLIGHTS_OF_DISCUSSION                 1
# RM_BM_NAME_PHONE_NUMBER                  1
# RM_BM_EMAIL                              1
# STATUS_UPDATE                           33
# CHALLENGES                              73
# PROPOSED_NEXT_STEPS                     43
# STATE                                    3
# TARGET                                   0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
missing_categorical_columns = []

# %%
new_dict = dict(df.isna().sum())

# %%
new_dict
# Out:
# {'S/N': 0,
#  'DATE': 0,
#  'NAME_OF_ENTITY': 2,
#  'NATURE_OF_BUSINESS': 1,
#  'BUSINESS_PROJECT': 0,
#  'CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER': 0,
#  'PROPOSED_FACILITY_AMOUNT': 0,
#  'PURPOSE_OF_FACILITY': 3,
#  'VALUE_CHAIN_CATEGORY': 0,
#  'NAME_OF_BANK': 22,
#  'BORROWING_RELATIONSHIP': 0,
#  'FRESH_LOAN_REQUEST': 0,
#  'REQUEST_SUBMITTED_TO_BANK': 0,
#  'SECURITY_PROPOSED': 13,
#  'FEASIBILITY_STUDY_AVAILABLE': 0,
#  'HIGHLIGHTS_OF_DISCUSSION': 1,
#  'RM_BM_NAME_PHONE_NUMBER': 1,
#  'RM_BM_EMAIL': 1,
#  'STATUS_UPDATE': 33,
#  'CHALLENGES': 73,
#  'PROPOSED_NEXT_STEPS': 43,
#  'STATE': 3,
#  'TARGET': 0}

# %%
# figuring out features with missing features
for k,v in new_dict.items():
    if v != 0:
        missing_categorical_columns.append(k)

# %%
missing_categorical_columns
# Out:
# ['NAME_OF_ENTITY',
#  'NATURE_OF_BUSINESS',
#  'PURPOSE_OF_FACILITY',
#  'NAME_OF_BANK',
#  'SECURITY_PROPOSED',
#  'HIGHLIGHTS_OF_DISCUSSION',
#  'RM_BM_NAME_PHONE_NUMBER',
#  'RM_BM_EMAIL',
#  'STATUS_UPDATE',
#  'CHALLENGES',
#  'PROPOSED_NEXT_STEPS',
#  'STATE']

# %%
from typing import List
def fill_categorical_columns_with_mode(col_list: List[str]) -> None:
    """ function that fills categoical columns with missing values
    with the column mode values
    """
    
    for col in col_list:
        mode_c = df[col].mode()[0]
        df[col].fillna(mode_c, inplace=True)
    return


fill_categorical_columns_with_mode(missing_categorical_columns)

# %%
df.isna().sum()
# Out:
# S/N                                     0
# DATE                                    0
# NAME_OF_ENTITY                          0
# NATURE_OF_BUSINESS                      0
# BUSINESS_PROJECT                        0
# CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER    0
# PROPOSED_FACILITY_AMOUNT                0
# PURPOSE_OF_FACILITY                     0
# VALUE_CHAIN_CATEGORY                    0
# NAME_OF_BANK                            0
# BORROWING_RELATIONSHIP                  0
# FRESH_LOAN_REQUEST                      0
# REQUEST_SUBMITTED_TO_BANK               0
# SECURITY_PROPOSED                       0
# FEASIBILITY_STUDY_AVAILABLE             0
# HIGHLIGHTS_OF_DISCUSSION                0
# RM_BM_NAME_PHONE_NUMBER                 0
# RM_BM_EMAIL                             0
# STATUS_UPDATE                           0
# CHALLENGES                              0
# PROPOSED_NEXT_STEPS                     0
# STATE                                   0
# TARGET                                  0
# dtype: int64

# %%
df['BUSINESS_PROJECT']
# Out:
# 0      EXISTING
# 1      EXISTING
# 2      EXISTING
# 3      EXISTING
# 4      EXISTING
#          ...
# 238    EXISTING
# 239    EXISTING
# 240    EXISTING
# 241    EXISTING
# 242    EXISTING
# Name: BUSINESS_PROJECT, Length: 243, dtype: object

# %%
df.head()
# Out:
#    S/N      DATE NAME_OF_ENTITY                      NATURE_OF_BUSINESS  \
# 0    1  1/2/2023       COM10001                         RICE PROCESSING
# 1    2  1/2/2023       COM10002  FERTILIZER DISTRIBUTION ACROSS ADAMAWA
# 2    3  1/2/2023       COM10003                     BULL FEED FINISHING
# 3    4  1/2/2023       COM10004                     BULL FEED FINISHING
# 4    5  1/2/2023       COM10005                     BULL FEED FINISHING
#
#   BUSINESS_PROJECT CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER  \
# 0         EXISTING                              OB10001
# 1         EXISTING                              OB10002
# 2         EXISTING                              OB10003
# 3         EXISTING                              OB10004
# 4         EXISTING                              OB10005
#
#    PROPOSED_FACILITY_AMOUNT          PURPOSE_OF_FACILITY VALUE_CHAIN_CATEGORY  \
# 0              2.000000e+09  WORKING CAPITAL ENHANCEMENT            MIDSTREAM
# 1              5.000000e+07  WORKING CAPITAL ENHANCEMENT         PRE-UPSTREAM
# 2              9.000000e+06  WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 3              1.000000e+05  WORKING CAPITAL ENHANCEMENT             UPSTREAM
# 4              5.000000e+06  WORKING CAPITAL ENHANCEMENT             UPSTREAM
#
#         NAME_OF_BANK  ...    SECURITY_PROPOSED FEASIBILITY_STUDY_AVAILABLE  \
# 0  FIDELITY BANK PLC  ...                  NIL                         YES
# 1  FIDELITY BANK PLC  ...                  NIL                         YES
# 2       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
# 3       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
# 4       STANBIC IBTC  ...  EQUITY CONTRIBUTION                         YES
#
#   HIGHLIGHTS_OF_DISCUSSION RM_BM_NAME_PHONE_NUMBER RM_BM_EMAIL  \
# 0                      NIL                     NIL         NIL
# 1                      NIL                     NIL         NIL
# 2                      NIL                     NIL         NIL
# 3                      NIL                     NIL         NIL
# 4                      NIL                     NIL         NIL
#
#                                        STATUS_UPDATE  \
# 0  WE AREAWAITING CREDIT COMMITY DECITION ON WEAT...
# 1  WE ARE CURRENTLY WAITING FOR THE CLIENT TO CHO...
# 2                       DOCUMENT YET TO BE PRESENTED
# 3                       DOCUMENT YET TO BE PRESENTED
# 4                       DOCUMENT YET TO BE PRESENTED
#
#                                           CHALLENGES  \
# 0                                               NONE
# 1  THE CLIENT IS ONLY WILLING TO DISTRIBUTE CRYST...
# 2                                                NIL
# 3                                                NIL
# 4                                                NIL
#
#                   PROPOSED_NEXT_STEPS    STATE TARGET
# 0  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
# 1                             ONBOARD  ADAMAWA      1
# 2  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
# 3  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      0
# 4  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
#
# [5 rows x 23 columns]

# %%
# Encoding
categorical_x_features = ['BUSINESS_PROJECT', 'VALUE_CHAIN_CATEGORY',
                          'BORROWING_RELATIONSHIP', 'FRESH_LOAN_REQUEST',
                          'REQUEST_SUBMITTED_TO_BANK', 'FEASIBILITY_STUDY_AVAILABLE']

# Function to create encoder dictionaries
def encoder(feature: str) -> dict:
    """ Function that handles encoding """
    encoder_dict = {item: index for index, item in enumerate(df[feature].unique())}
    return encoder_dict

# Creating encoder dictionaries for each categorical feature
encoder_dicts = {feature: encoder(feature) for feature in categorical_x_features}

# Replace categorical values with their corresponding encodings
for feature, encoder_dict in encoder_dicts.items():
    df[feature] = df[feature].replace(encoder_dict)

# %%
df['BUSINESS_PROJECT']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 238    0
# 239    0
# 240    0
# 241    0
# 242    0
# Name: BUSINESS_PROJECT, Length: 243, dtype: int64

# %%
print(encoder_dicts)
# Out:
# {'BUSINESS_PROJECT': {'EXISTING': 0, 'NEW  ': 1}, 'VALUE_CHAIN_CATEGORY': {'MIDSTREAM': 0, 'PRE-UPSTREAM': 1, 'UPSTREAM': 2, 'DOWNSTREAM': 3, 'UPSTREAM AND MIDSTREAM': 4, 'MIDSTREAM AND DOWNSTREAM': 5, 'UPSTREAM AND DOWNSTREAM': 6}, 'BORROWING_RELATIONSHIP': {'YES': 0, 'NO': 1}, 'FRESH_LOAN_REQUEST': {'YES': 0, 'NO': 1}, 'REQUEST_SUBMITTED_TO_BANK': {'YES': 0, 'NO': 1}, 'FEASIBILITY_STUDY_AVAILABLE': {'YES': 0, 'NO': 1, 'NIL': 2}}

# %%
# to be sure that the encoding was succesful
for i in categorical_x_features:
    print(df[i].unique())
# Out:
# [0 1]
# [0 1 2 3 4 5 6]
# [0 1]
# [0 1]
# [0 1]
# [0 1 2]

# %%
df.head()
# Out:
#    S/N      DATE NAME_OF_ENTITY                      NATURE_OF_BUSINESS  \
# 0    1  1/2/2023       COM10001                         RICE PROCESSING
# 1    2  1/2/2023       COM10002  FERTILIZER DISTRIBUTION ACROSS ADAMAWA
# 2    3  1/2/2023       COM10003                     BULL FEED FINISHING
# 3    4  1/2/2023       COM10004                     BULL FEED FINISHING
# 4    5  1/2/2023       COM10005                     BULL FEED FINISHING
#
#    BUSINESS_PROJECT CONTACT_NAME_PHONE_EMAIL_OF_PROMOTER  \
# 0                 0                              OB10001
# 1                 0                              OB10002
# 2                 0                              OB10003
# 3                 0                              OB10004
# 4                 0                              OB10005
#
#    PROPOSED_FACILITY_AMOUNT          PURPOSE_OF_FACILITY  \
# 0              2.000000e+09  WORKING CAPITAL ENHANCEMENT
# 1              5.000000e+07  WORKING CAPITAL ENHANCEMENT
# 2              9.000000e+06  WORKING CAPITAL ENHANCEMENT
# 3              1.000000e+05  WORKING CAPITAL ENHANCEMENT
# 4              5.000000e+06  WORKING CAPITAL ENHANCEMENT
#
#    VALUE_CHAIN_CATEGORY       NAME_OF_BANK  ...    SECURITY_PROPOSED  \
# 0                     0  FIDELITY BANK PLC  ...                  NIL
# 1                     1  FIDELITY BANK PLC  ...                  NIL
# 2                     2       STANBIC IBTC  ...  EQUITY CONTRIBUTION
# 3                     2       STANBIC IBTC  ...  EQUITY CONTRIBUTION
# 4                     2       STANBIC IBTC  ...  EQUITY CONTRIBUTION
#
#    FEASIBILITY_STUDY_AVAILABLE  HIGHLIGHTS_OF_DISCUSSION  \
# 0                            0                       NIL
# 1                            0                       NIL
# 2                            0                       NIL
# 3                            0                       NIL
# 4                            0                       NIL
#
#   RM_BM_NAME_PHONE_NUMBER  RM_BM_EMAIL  \
# 0                     NIL          NIL
# 1                     NIL          NIL
# 2                     NIL          NIL
# 3                     NIL          NIL
# 4                     NIL          NIL
#
#                                        STATUS_UPDATE  \
# 0  WE AREAWAITING CREDIT COMMITY DECITION ON WEAT...
# 1  WE ARE CURRENTLY WAITING FOR THE CLIENT TO CHO...
# 2                       DOCUMENT YET TO BE PRESENTED
# 3                       DOCUMENT YET TO BE PRESENTED
# 4                       DOCUMENT YET TO BE PRESENTED
#
#                                           CHALLENGES  \
# 0                                               NONE
# 1  THE CLIENT IS ONLY WILLING TO DISTRIBUTE CRYST...
# 2                                                NIL
# 3                                                NIL
# 4                                                NIL
#
#                   PROPOSED_NEXT_STEPS    STATE TARGET
# 0  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
# 1                             ONBOARD  ADAMAWA      1
# 2  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
# 3  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      0
# 4  AWATING FEEDBACK FROM THE PROSPECT  ADAMAWA      1
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Model Selection and Training

# %%
# using xgboost algorithm
xgboost = xgb.XGBClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[553], line 2
#       1 # using xgboost algorithm
# ----> 2 xgboost = xgb.XGBClassifier()
#
# NameError: name 'xgb' is not defined

# %%
xgboost_model = xgboost.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[554], line 1
# ----> 1 xgboost_model = xgboost.fit(x_train, y_train)
#
# NameError: name 'xgboost' is not defined

# %%
xgb_prediction = xgboost_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[496], line 1
# ----> 1 xgb_prediction = xgboost_model.predict(x_test)
#
# NameError: name 'xgboost_model' is not defined

# %%
accuracy_score(xgb_prediction, y_test)

# %%
# saving the model
joblib.dump(xgboost_model, '/')

# %%
# using catboost algorithm

# %%
catboost = CatboostClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[392], line 1
# ----> 1 catboost = CatboostClassifier()
#
# NameError: name 'CatboostClassifier' is not defined

# %%
catboost_model = catboost.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[393], line 1
# ----> 1 catboost_model = catboost.fit(x_train, y_train)
#
# NameError: name 'catboost' is not defined

# %%
catboost_prediction = catboost_model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[394], line 1
# ----> 1 catboost_prediction = catboost_model.predict(x_test)
#
# NameError: name 'catboost_model' is not defined

# %%
accuracy_score(catboost_prediction, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[395], line 1
# ----> 1 accuracy_score(catboost_prediction, y_test)
#
# NameError: name 'catboost_prediction' is not defined

# %%
joblib.dump(xgboost_model, '/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[396], line 1
# ----> 1 joblib.dump(xgboost_model, '/')
#
# NameError: name 'joblib' is not defined
